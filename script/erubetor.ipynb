# %% [markdown]
# ## Zis is an elevator

# %%
from statsmodels.graphics.tsaplots import plot_acf
import numpy as np
import matplotlib.pyplot as plt

x = np.random.normal(0, 1, 1000)  # white noise
plot_acf(x, lags=40)
plt.show()
